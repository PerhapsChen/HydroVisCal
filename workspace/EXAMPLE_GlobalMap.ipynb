# %%
import sys
sys.path.append('../scripts')

import os
import json

import numpy as np
import xarray as xr
import matplotlib as mpl
import matplotlib.pyplot as plt

import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
# %load_ext autoreload
# %autoreload 2
from HYDRO_MapPlot import genGlobalMapJson, GlobalMapPlot

# %%
from HYDRO_Generator import *

# %%
genGlobalMapJson('./hydroJson/GlobalMap.json')
# Out:
# Json file of parameters has written to [./hydroJson/GlobalMap.json]

# %%
data = np.random.rand(1800, 3600)
lat = LatCoords(90, -90, 0.1)
lon = LonCoords(-180, 180, 0.1)

# %%
b = GlobalMapPlot()
b.baseMap()
# b.ax.plot([114,20],[40, 20], transform=ccrs.PlateCarree())
# b.ax.get_extent(ccrs.PlateCarree())
# b.stackImage(data[0], lat, lon)
b.stackImage(data=data, lon=lon, lat=lat)

# %%
from HYDRO_Plot import ColorBarFromFig

# %%
cbar = ColorBarFromFig()
