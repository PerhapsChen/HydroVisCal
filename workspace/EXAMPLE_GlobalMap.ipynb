# %%
import sys
sys.path.append('../scripts')

import os
import json

import numpy as np
import xarray as xr
import matplotlib as mpl
import matplotlib.pyplot as plt

import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
# %load_ext autoreload
# %autoreload 2
from HYDRO_MapPlot import genGlobalMapJson, GlobalMapPlot
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
genGlobalMapJson('./hydroJson/GlobalMap.json')
# Out:
# Json file of parameters has written to [./hydroJson/GlobalMap.json]

# %%
import xarray as xr
ds = xr.open_dataset('../data/lai_jjj_annual.nc')
lon = ds.lon.values
lat = ds.lat.values
data = ds.lai.values

# %%
data = np.arange(160)
lat = np.arange(-80, 80, 1)
lon = np.arange(-80, 80, 1)

# %%
len(data), len(lat)
# Out:
# (160, 160)

# %%
b = GlobalMapPlot()
b.baseMap()
# b.ax.plot([114,20],[40, 20], transform=ccrs.PlateCarree())
# b.ax.get_extent(ccrs.PlateCarree())
# b.stackImage(data[0], lat, lon)
b.stackScatter(data=data, lon=lon, lat=lat)
