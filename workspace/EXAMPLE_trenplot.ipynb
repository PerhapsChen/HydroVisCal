# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../scripts')

import numpy as np

from HYDRO_Plot import TrendPlot,genTrendPlotJson

# %%
genTrendPlotJson()
# Out:
# Json file of parameters has written to [./hydroJson/TrendPlot.json]

# %%
tp = TrendPlot()

# %%
x = np.arange(1980, 2020)
y = (x-1980)*0.02+np.random.rand(x.shape[0])

# %%
tp.plot(x,y)
