# %%
import sys
sys.path.append('../scripts')

import os
import json

import numpy as np
import xarray as xr
import matplotlib as mpl
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
from HYDRO_Plot import TrendPlot,genTrendPlotJson
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
genTrendPlotJson()
# Out:
# Json file of parameters has written to [./hydroJson/TrendPlot.json]

# %%
tp = TrendPlot()

# %%
from HYDRO_Stats import gen,TrendDetector

# %%
x = np.arange(1980, 2020)
y = np.random.rand(x.shape[0])

# %%
tp.plot(x,y)
